# %% [markdown]
# # Model Training
#
# Train LSTM-based models and evaluate with MSE, R^2, and predicted degredation.

# %%
import sys
sys.path.append('/content/drive/MyDrive/msc_data_analytics_thesis_project_pose_estimation')

# %%
# ✅ Environment Setup
from utils.setup import setup_environment
base_path = setup_environment(mount_gdrive=True)

import os
import json
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
from tensorflow.keras.losses import Huber
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from tensorflow.keras.layers import LSTM, Bidirectional, GRU, SimpleRNN, Dense, Dropout, Input, BatchNormalization, Conv1D

from utils.config import ENGINEERED_DIR, PROCESSED_DIR, EXERCISES, RESULTS_DIR
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Environment set. Project base path: /content/drive/MyDrive/pose-estimation-research

# %%
def save_individual_plots(history, y_true, y_pred, params, exercise_dir, sample_size=50):
    """Save each visualization as separate image file"""
    y_true = np.array(y_true).flatten()
    y_pred = np.array(y_pred).flatten()
    errors = y_true - y_pred
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)

    # 1. Loss curves plot
    plt.figure(figsize=(8, 5))
    plt.plot(history.history['loss'], label='Train')
    plt.plot(history.history['val_loss'], label='Validation')
    plt.title(f"{params['exercise']} ({params['features']}) - Training & Validation Loss")
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid(True)
    loss_path = os.path.join(exercise_dir, f"{params['exercise']}_{params['features']}_loss_curves.png")
    plt.savefig(loss_path)
    plt.close()

    # 2. Prediction scatter plot
    plt.figure(figsize=(8, 5))
    plt.scatter(y_true, y_pred, alpha=0.3)
    plt.plot([min(y_true), max(y_true)], [min(y_true), max(y_true)], 'k--')
    plt.title(f"{params['exercise']} ({params['features']})\nPredictions vs Truth (MAE: {mae:.4f}, R2: {r2:.4f})")
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.grid(True)
    scatter_path = os.path.join(exercise_dir, f"{params['exercise']}_{params['features']}_scatter.png")
    plt.savefig(scatter_path)
    plt.close()

    # 3. Error distribution plot
    plt.figure(figsize=(8, 5))
    sns.histplot(errors, kde=True)
    plt.title(f"{params['exercise']} ({params['features']}) - Error Distribution")
    plt.xlabel('Prediction Error')
    plt.grid(True)
    error_path = os.path.join(exercise_dir, f"{params['exercise']}_{params['features']}_errors.png")
    plt.savefig(error_path)
    plt.close()

    # 4. Line plot comparison
    plt.figure(figsize=(12, 5))
    sample_size = min(sample_size, len(y_true))
    plt.plot(y_true[:sample_size], label="True", marker='o', markersize=3)
    plt.plot(y_pred[:sample_size], label="Predicted", alpha=0.7, linestyle='--', marker='x', markersize=3)
    plt.title(f"{params['exercise']} ({params['features']}) - First {sample_size} Samples Comparison")
    plt.xlabel("Sample index")
    plt.ylabel("Value")
    plt.legend()
    plt.grid(True)
    line_path = os.path.join(exercise_dir, f"{params['exercise']}_{params['features']}_line_comparison.png")
    plt.savefig(line_path)
    plt.close()

    return {
        'loss_plot': loss_path,
        'scatter_plot': scatter_path,
        'error_plot': error_path,
        'line_plot': line_path
    }

# %%
def save_enhanced_results(history, y_true, y_pred, params, exercise_dir):
    """Save all results including individual plots"""
    # Save individual plots
    plot_paths = save_individual_plots(history, y_true, y_pred, params, exercise_dir)

    # Calculate metrics
    y_true = np.array(y_true).flatten()
    y_pred = np.array(y_pred).flatten()

    metrics = {
        'final_train_loss': history.history['loss'][-1],
        'final_val_loss': history.history['val_loss'][-1],
        'final_train_mae': history.history['mae'][-1],
        'final_val_mae': history.history['val_mae'][-1],
        'prediction_mae': mean_absolute_error(y_true, y_pred),
        'prediction_r2': r2_score(y_true, y_pred),
        'num_epochs_run': len(history.history['loss']),
        'best_epoch': np.argmin(history.history['val_loss']) + 1,
        **plot_paths  # Add paths to the individual plots
    }

    # Combine parameters and metrics
    results = {**params, **metrics}

    # Save as CSV
    csv_filename = f"{params['exercise']}_{params['features']}_metrics.csv"
    csv_path = os.path.join(exercise_dir, csv_filename)
    pd.DataFrame([results]).to_csv(csv_path, index=False)

    return results

# %%
def load_and_preprocess_data(exercise: str, augment_with_features: bool = True):
    """Load and preprocess the data with proper validation"""
    dir_path = os.path.join(ENGINEERED_DIR, exercise)

    # Determine which feature file to load
    feature_file = "X_featured.npy" if augment_with_features else "X.npy"
    feature_path = os.path.join(dir_path, feature_file)
    target_path = os.path.join(dir_path, "y.npy")

    # Validate files exist
    if not os.path.exists(feature_path):
        raise FileNotFoundError(f"Feature file not found: {feature_path}")
    if not os.path.exists(target_path):
        raise FileNotFoundError(f"Target file not found: {target_path}")

    try:
        X = np.load(feature_path)
        y = np.load(target_path)

        # Validate shapes
        if len(X) != len(y):
            raise ValueError(f"X and y have different lengths: {len(X)} vs {len(y)}")

        if X.ndim != 3:  # Should be (samples, timesteps, features)
            raise ValueError(f"X should be 3D array, got {X.ndim}D")

        # Robust scaling for features
        original_shape = X.shape
        scaler_x = RobustScaler()
        X = scaler_x.fit_transform(X.reshape(-1, X.shape[-1])).reshape(original_shape)

        # Scale targets to [0,1] with epsilon to avoid division by zero
        y_min, y_max = y.min(), y.max()
        y_range = y_max - y_min
        if y_range < 1e-10:  # Handle near-constant y
            y_range = 1.0
        y = (y - y_min) / y_range

        return X, y

    except Exception as e:
        raise RuntimeError(f"Error loading {exercise} data: {str(e)}")

# %%
def build_enhanced_rnn(input_shape):
    """Build model with proper output shape"""
    inputs = Input(shape=input_shape)
    conv = Conv1D(64, kernel_size=3, activation='relu', padding='same')(inputs)
    conv = BatchNormalization()(conv)
    conv = Dropout(0.2)(conv)

    gru = GRU(128, return_sequences=False)(conv)
    gru = BatchNormalization()(gru)
    gru = Dropout(0.3)(gru)

    dense = Dense(128, activation='relu')(gru)
    dense = Dropout(0.3)(dense)
    output = Dense(1)(dense)

    return Model(inputs=inputs, outputs=output)

# %%
def train_enhanced_model(X, y, exercise_name, augment_flag):
    """Training with proper validation set handling"""
    # Create exercise-specific results directory
    feature_type = "featured" if augment_flag else "basic"
    exercise_dir = os.path.join(RESULTS_DIR, exercise_name, feature_type)
    os.makedirs(exercise_dir, exist_ok=True)

    # Stratified split
    y_bins = np.digitize(y, bins=np.quantile(y, [0.25, 0.5, 0.75]))
    X_train, X_val, y_train, y_val = train_test_split(
        X, y, test_size=0.2, stratify=y_bins, random_state=42
    )

    model = build_enhanced_rnn(X.shape[1:])

    # Experiment parameters
    params = {
        'exercise': exercise_name,
        'features': feature_type,
        'learning_rate': 0.005,
        'loss': 'huber',
        'batch_size': 32,
        'epochs': 100,
        'dropout_rates': [0.2, 0.3, 0.3],
        'architecture': 'Conv1D(64)-GRU(128)-Dense(128)',
        'early_stopping_patience': 20,
        'reduce_lr_patience': 10,
        'input_shape': X.shape[1:]
    }

    model.compile(
        optimizer=Adam(learning_rate=params['learning_rate']),
        loss=params['loss'],
        metrics=['mae']
    )

    callbacks = [
        EarlyStopping(patience=params['early_stopping_patience'], restore_best_weights=True),
        ReduceLROnPlateau(factor=0.5, patience=params['reduce_lr_patience'], min_lr=1e-6)
    ]

    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=params['epochs'],
        batch_size=params['batch_size'],
        callbacks=callbacks,
        verbose=1
    )

    return model, history, X_val, y_val, params

# %%
def run_experiment(exercise, augment_flag):
    """Run full experiment for one exercise with specified feature type"""
    try:
        feature_type = "featured" if augment_flag else "basic"
        print(f"\n{'='*50}")
        print(f"Starting experiment for: {exercise} ({feature_type} features)")
        print(f"{'='*50}")

        # Load data
        X, y = load_and_preprocess_data(exercise, augment_with_features=augment_flag)

        # Train model
        model, history, X_val, y_val, params = train_enhanced_model(
            X, y, exercise, augment_flag
        )

        # Predict and evaluate
        y_pred = model.predict(X_val)

        # Debug shapes
        print(f"Shapes - y_val: {y_val.shape}, y_pred: {y_pred.shape}")

        # Flatten arrays
        y_val_flat = y_val.flatten()
        y_pred_flat = y_pred.flatten()

        # Save results
        exercise_dir = os.path.join(RESULTS_DIR, exercise, feature_type)
        results = save_enhanced_results(
            history, y_val_flat, y_pred_flat, params, exercise_dir
        )

        # Print summary
        print(f"\nCompleted experiment for: {exercise} ({feature_type} features)")
        print(f"Final Validation MAE: {results['prediction_mae']:.4f}")
        print(f"Final Validation R2: {results['prediction_r2']:.4f}")
        print(f"Results saved to: {exercise_dir}")

        return results

    except Exception as e:
        print(f"Error occurred for {exercise} ({'featured' if augment_flag else 'basic'}): {str(e)}")
        if 'y_pred' in locals():
            print(f"y_pred shape: {y_pred.shape}")
        if 'y_val' in locals():
            print(f"y_val shape: {y_val.shape}")
        return None

# %%
def generate_comparison_tables(all_results):
    """Generate comparison tables and visualizations"""
    if not all_results:
        return

    df = pd.DataFrame(all_results)

    # Save full results
    full_results_path = os.path.join(RESULTS_DIR, "all_experiments_full_results.csv")
    df.to_csv(full_results_path, index=False)

    # Create comparison tables
    comparison_dir = os.path.join(RESULTS_DIR, "comparisons")
    os.makedirs(comparison_dir, exist_ok=True)

    # 1. Basic metrics comparison
    metric_cols = ['exercise', 'features', 'prediction_mae', 'prediction_r2',
                  'num_epochs_run', 'final_val_loss']
    metrics_df = df[metric_cols].sort_values(['exercise', 'features'])
    metrics_path = os.path.join(comparison_dir, "key_metrics_comparison.csv")
    metrics_df.to_csv(metrics_path, index=False)

    # 2. Feature augmentation impact
    feat_impact = df.pivot_table(
        index='exercise',
        columns='features',
        values=['prediction_mae', 'prediction_r2'],
        aggfunc='mean'
    )
    feat_impact_path = os.path.join(comparison_dir, "feature_augmentation_impact.csv")
    feat_impact.to_csv(feat_impact_path)

    # 3. Create visual comparison plots
    plt.figure(figsize=(12, 6))

    # MAE comparison
    plt.subplot(1, 2, 1)
    sns.barplot(data=df, x='exercise', y='prediction_mae', hue='features')
    plt.title('MAE Comparison by Exercise and Features')
    plt.ylabel('MAE')
    plt.xticks(rotation=45)

    # R2 comparison
    plt.subplot(1, 2, 2)
    sns.barplot(data=df, x='exercise', y='prediction_r2', hue='features')
    plt.title('R2 Comparison by Exercise and Features')
    plt.ylabel('R2 Score')
    plt.xticks(rotation=45)

    plt.tight_layout()
    plot_path = os.path.join(comparison_dir, "metrics_comparison.png")
    plt.savefig(plot_path)
    plt.close()

    print(f"\nComparison tables and plots saved to: {comparison_dir}")

# %%
def main():
    """Run experiments for all exercises and feature types"""
    all_results = []

    for exercise in EXERCISES:
        # Run with basic features
        basic_results = run_experiment(exercise, augment_flag=False)
        if basic_results:
            all_results.append(basic_results)

        # Run with augmented features
        featured_results = run_experiment(exercise, augment_flag=True)
        if featured_results:
            all_results.append(featured_results)

    # Generate comparison tables and plots
    generate_comparison_tables(all_results)

    # Print final summary
    if all_results:
        summary_df = pd.DataFrame(all_results)
        print("\nExperiment Summary:")
        print(summary_df[['exercise', 'features', 'prediction_mae', 'prediction_r2',
                         'num_epochs_run', 'final_val_loss']].to_string(index=False))
    else:
        print("\nNo experiments completed successfully.")

# %%
main()
# Out:
# ==================================================
# Starting experiment for: squat (basic features)
# ==================================================
# Epoch 1/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.6424 - mae: 1.0415 - val_loss: 0.0723 - val_mae: 0.3155 - learning_rate: 0.0050
# Epoch 2/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.2267 - mae: 0.5485 - val_loss: 0.0587 - val_mae: 0.2848 - learning_rate: 0.0050
# Epoch 3/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0719 - mae: 0.2998 - val_loss: 0.0475 - val_mae: 0.2524 - learning_rate: 0.0050
# Epoch 4/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0496 - mae: 0.2516 - val_loss: 0.0547 - val_mae: 0.2730 - learning_rate: 0.0050
# Epoch 5/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0324 - mae: 0.1988 - val_loss: 0.0403 - val_mae: 0.2314 - learning_rate: 0.0050
# Epoch 6/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0272 - mae: 0.1830 - val_loss: 0.0308 - val_mae: 0.2016 - learning_rate: 0.0050
# Epoch 7/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0240 - mae: 0.1722 - val_loss: 0.0288 - val_mae: 0.1941 - learning_rate: 0.0050
# Epoch 8/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0216 - mae: 0.1642 - val_loss: 0.0275 - val_mae: 0.1901 - learning_rate: 0.0050
# Epoch 9/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0208 - mae: 0.1594 - val_loss: 0.0258 - val_mae: 0.1840 - learning_rate: 0.0050
# Epoch 10/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0185 - mae: 0.1505 - val_loss: 0.0221 - val_mae: 0.1705 - learning_rate: 0.0050
# Epoch 11/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0196 - mae: 0.1561 - val_loss: 0.0207 - val_mae: 0.1647 - learning_rate: 0.0050
# Epoch 12/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0181 - mae: 0.1498 - val_loss: 0.0236 - val_mae: 0.1760 - learning_rate: 0.0050
# Epoch 13/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0172 - mae: 0.1458 - val_loss: 0.0250 - val_mae: 0.1836 - learning_rate: 0.0050
# Epoch 14/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0160 - mae: 0.1399 - val_loss: 0.0230 - val_mae: 0.1758 - learning_rate: 0.0050
# Epoch 15/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0150 - mae: 0.1352 - val_loss: 0.0218 - val_mae: 0.1714 - learning_rate: 0.0050
# Epoch 16/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0145 - mae: 0.1295 - val_loss: 0.0182 - val_mae: 0.1538 - learning_rate: 0.0050
# Epoch 17/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0134 - mae: 0.1273 - val_loss: 0.0179 - val_mae: 0.1511 - learning_rate: 0.0050
# Epoch 18/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0144 - mae: 0.1324 - val_loss: 0.0143 - val_mae: 0.1311 - learning_rate: 0.0050
# Epoch 19/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0155 - mae: 0.1357 - val_loss: 0.0151 - val_mae: 0.1377 - learning_rate: 0.0050
# Epoch 20/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0141 - mae: 0.1301 - val_loss: 0.0155 - val_mae: 0.1391 - learning_rate: 0.0050
# Epoch 21/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0132 - mae: 0.1253 - val_loss: 0.0138 - val_mae: 0.1297 - learning_rate: 0.0050
# Epoch 22/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0142 - mae: 0.1296 - val_loss: 0.0145 - val_mae: 0.1317 - learning_rate: 0.0050
# Epoch 23/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0138 - mae: 0.1297 - val_loss: 0.0123 - val_mae: 0.1195 - learning_rate: 0.0050
# Epoch 24/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0151 - mae: 0.1346 - val_loss: 0.0140 - val_mae: 0.1293 - learning_rate: 0.0050
# Epoch 25/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0144 - mae: 0.1303 - val_loss: 0.0147 - val_mae: 0.1342 - learning_rate: 0.0050
# Epoch 26/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0118 - mae: 0.1169 - val_loss: 0.0141 - val_mae: 0.1315 - learning_rate: 0.0050
# Epoch 27/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0123 - mae: 0.1219 - val_loss: 0.0123 - val_mae: 0.1180 - learning_rate: 0.0050
# Epoch 28/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0131 - mae: 0.1240 - val_loss: 0.0153 - val_mae: 0.1364 - learning_rate: 0.0050
# Epoch 29/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0136 - mae: 0.1260 - val_loss: 0.0122 - val_mae: 0.1193 - learning_rate: 0.0050
# Epoch 30/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0124 - mae: 0.1208 - val_loss: 0.0128 - val_mae: 0.1232 - learning_rate: 0.0050
# Epoch 31/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0129 - mae: 0.1253 - val_loss: 0.0122 - val_mae: 0.1193 - learning_rate: 0.0050
# Epoch 32/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0106 - mae: 0.1124 - val_loss: 0.0131 - val_mae: 0.1261 - learning_rate: 0.0050
# Epoch 33/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0121 - mae: 0.1194 - val_loss: 0.0126 - val_mae: 0.1189 - learning_rate: 0.0050
# Epoch 34/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0110 - mae: 0.1107 - val_loss: 0.0111 - val_mae: 0.1134 - learning_rate: 0.0050
# Epoch 35/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0112 - mae: 0.1146 - val_loss: 0.0104 - val_mae: 0.1084 - learning_rate: 0.0050
# Epoch 36/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0106 - mae: 0.1083 - val_loss: 0.0120 - val_mae: 0.1167 - learning_rate: 0.0050
# Epoch 37/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0112 - mae: 0.1121 - val_loss: 0.0120 - val_mae: 0.1170 - learning_rate: 0.0050
# Epoch 38/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0107 - mae: 0.1107 - val_loss: 0.0113 - val_mae: 0.1136 - learning_rate: 0.0050
# Epoch 39/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0116 - mae: 0.1152 - val_loss: 0.0101 - val_mae: 0.1080 - learning_rate: 0.0050
# Epoch 40/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0102 - mae: 0.1081 - val_loss: 0.0128 - val_mae: 0.1220 - learning_rate: 0.0050
# Epoch 41/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0104 - mae: 0.1117 - val_loss: 0.0118 - val_mae: 0.1142 - learning_rate: 0.0050
# Epoch 42/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0097 - mae: 0.1062 - val_loss: 0.0121 - val_mae: 0.1180 - learning_rate: 0.0050
# Epoch 43/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0103 - mae: 0.1078 - val_loss: 0.0125 - val_mae: 0.1183 - learning_rate: 0.0050
# Epoch 44/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0100 - mae: 0.1074 - val_loss: 0.0116 - val_mae: 0.1146 - learning_rate: 0.0050
# Epoch 45/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0113 - mae: 0.1141 - val_loss: 0.0142 - val_mae: 0.1284 - learning_rate: 0.0050
# Epoch 46/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0097 - mae: 0.1054 - val_loss: 0.0106 - val_mae: 0.1107 - learning_rate: 0.0050
# Epoch 47/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0108 - mae: 0.1104 - val_loss: 0.0109 - val_mae: 0.1088 - learning_rate: 0.0050
# Epoch 48/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0110 - mae: 0.1148 - val_loss: 0.0116 - val_mae: 0.1130 - learning_rate: 0.0050
# Epoch 49/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0095 - mae: 0.1031 - val_loss: 0.0090 - val_mae: 0.1007 - learning_rate: 0.0050
# Epoch 50/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0107 - mae: 0.1129 - val_loss: 0.0092 - val_mae: 0.1024 - learning_rate: 0.0050
# Epoch 51/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0096 - mae: 0.1044 - val_loss: 0.0117 - val_mae: 0.1148 - learning_rate: 0.0050
# Epoch 52/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0109 - mae: 0.1139 - val_loss: 0.0108 - val_mae: 0.1108 - learning_rate: 0.0050
# Epoch 53/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0092 - mae: 0.1020 - val_loss: 0.0122 - val_mae: 0.1167 - learning_rate: 0.0050
# Epoch 54/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0114 - mae: 0.1147 - val_loss: 0.0101 - val_mae: 0.1057 - learning_rate: 0.0050
# Epoch 55/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0091 - mae: 0.1015 - val_loss: 0.0094 - val_mae: 0.1032 - learning_rate: 0.0050
# Epoch 56/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0093 - mae: 0.1047 - val_loss: 0.0086 - val_mae: 0.0973 - learning_rate: 0.0050
# Epoch 57/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0089 - mae: 0.1001 - val_loss: 0.0101 - val_mae: 0.1066 - learning_rate: 0.0050
# Epoch 58/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0095 - mae: 0.1027 - val_loss: 0.0118 - val_mae: 0.1138 - learning_rate: 0.0050
# Epoch 59/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0100 - mae: 0.1092 - val_loss: 0.0097 - val_mae: 0.1035 - learning_rate: 0.0050
# Epoch 60/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0093 - mae: 0.1017 - val_loss: 0.0087 - val_mae: 0.1005 - learning_rate: 0.0050
# Epoch 61/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0110 - mae: 0.1112 - val_loss: 0.0112 - val_mae: 0.1112 - learning_rate: 0.0050
# Epoch 62/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0110 - mae: 0.1150 - val_loss: 0.0099 - val_mae: 0.1053 - learning_rate: 0.0050
# Epoch 63/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0086 - mae: 0.1011 - val_loss: 0.0090 - val_mae: 0.1018 - learning_rate: 0.0050
# Epoch 64/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0084 - mae: 0.1002 - val_loss: 0.0086 - val_mae: 0.0987 - learning_rate: 0.0050
# Epoch 65/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0098 - mae: 0.1058 - val_loss: 0.0107 - val_mae: 0.1113 - learning_rate: 0.0050
# Epoch 66/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0089 - mae: 0.1032 - val_loss: 0.0090 - val_mae: 0.0997 - learning_rate: 0.0050
# Epoch 67/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0075 - mae: 0.0912 - val_loss: 0.0084 - val_mae: 0.0955 - learning_rate: 0.0025
# Epoch 68/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0069 - mae: 0.0890 - val_loss: 0.0085 - val_mae: 0.0989 - learning_rate: 0.0025
# Epoch 69/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0079 - mae: 0.0934 - val_loss: 0.0080 - val_mae: 0.0946 - learning_rate: 0.0025
# Epoch 70/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0068 - mae: 0.0874 - val_loss: 0.0083 - val_mae: 0.0954 - learning_rate: 0.0025
# Epoch 71/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0065 - mae: 0.0860 - val_loss: 0.0095 - val_mae: 0.1004 - learning_rate: 0.0025
# Epoch 72/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0074 - mae: 0.0931 - val_loss: 0.0101 - val_mae: 0.1031 - learning_rate: 0.0025
# Epoch 73/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0063 - mae: 0.0851 - val_loss: 0.0086 - val_mae: 0.0986 - learning_rate: 0.0025
# Epoch 74/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0071 - mae: 0.0905 - val_loss: 0.0084 - val_mae: 0.0942 - learning_rate: 0.0025
# Epoch 75/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0068 - mae: 0.0874 - val_loss: 0.0085 - val_mae: 0.0973 - learning_rate: 0.0025
# Epoch 76/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0062 - mae: 0.0825 - val_loss: 0.0076 - val_mae: 0.0902 - learning_rate: 0.0025
# Epoch 77/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0057 - mae: 0.0815 - val_loss: 0.0084 - val_mae: 0.0932 - learning_rate: 0.0025
# Epoch 78/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0064 - mae: 0.0863 - val_loss: 0.0081 - val_mae: 0.0916 - learning_rate: 0.0025
# Epoch 79/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0074 - mae: 0.0899 - val_loss: 0.0084 - val_mae: 0.0967 - learning_rate: 0.0025
# Epoch 80/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0066 - mae: 0.0856 - val_loss: 0.0090 - val_mae: 0.0957 - learning_rate: 0.0025
# Epoch 81/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0065 - mae: 0.0880 - val_loss: 0.0099 - val_mae: 0.1040 - learning_rate: 0.0025
# Epoch 82/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0063 - mae: 0.0840 - val_loss: 0.0083 - val_mae: 0.0903 - learning_rate: 0.0025
# Epoch 83/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0073 - mae: 0.0888 - val_loss: 0.0088 - val_mae: 0.0951 - learning_rate: 0.0025
# Epoch 84/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0066 - mae: 0.0857 - val_loss: 0.0078 - val_mae: 0.0902 - learning_rate: 0.0025
# Epoch 85/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0068 - mae: 0.0871 - val_loss: 0.0080 - val_mae: 0.0902 - learning_rate: 0.0025
# Epoch 86/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0058 - mae: 0.0789 - val_loss: 0.0077 - val_mae: 0.0885 - learning_rate: 0.0025
# Epoch 87/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0057 - mae: 0.0788 - val_loss: 0.0070 - val_mae: 0.0832 - learning_rate: 0.0012
# Epoch 88/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0060 - mae: 0.0798 - val_loss: 0.0081 - val_mae: 0.0889 - learning_rate: 0.0012
# Epoch 89/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0051 - mae: 0.0754 - val_loss: 0.0070 - val_mae: 0.0846 - learning_rate: 0.0012
# Epoch 90/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0053 - mae: 0.0763 - val_loss: 0.0069 - val_mae: 0.0842 - learning_rate: 0.0012
# Epoch 91/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0049 - mae: 0.0725 - val_loss: 0.0071 - val_mae: 0.0849 - learning_rate: 0.0012
# Epoch 92/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0052 - mae: 0.0757 - val_loss: 0.0067 - val_mae: 0.0855 - learning_rate: 0.0012
# Epoch 93/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0063 - mae: 0.0826 - val_loss: 0.0071 - val_mae: 0.0858 - learning_rate: 0.0012
# Epoch 94/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0051 - mae: 0.0757 - val_loss: 0.0075 - val_mae: 0.0896 - learning_rate: 0.0012
# Epoch 95/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0058 - mae: 0.0799 - val_loss: 0.0070 - val_mae: 0.0853 - learning_rate: 0.0012
# Epoch 96/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0063 - mae: 0.0833 - val_loss: 0.0078 - val_mae: 0.0889 - learning_rate: 0.0012
# Epoch 97/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0052 - mae: 0.0767 - val_loss: 0.0076 - val_mae: 0.0894 - learning_rate: 0.0012
# Epoch 98/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0044 - mae: 0.0707 - val_loss: 0.0081 - val_mae: 0.0891 - learning_rate: 0.0012
# Epoch 99/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0056 - mae: 0.0801 - val_loss: 0.0069 - val_mae: 0.0845 - learning_rate: 0.0012
# Epoch 100/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0051 - mae: 0.0735 - val_loss: 0.0075 - val_mae: 0.0882 - learning_rate: 0.0012
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Shapes - y_val: (234,), y_pred: (234, 1)
#
# Completed experiment for: squat (basic features)
# Final Validation MAE: 0.0855
# Final Validation R2: 0.7027
# Results saved to: /content/drive/MyDrive/msc_data_analytics_thesis_project_pose_estimation/results/squat/basic
#
# ==================================================
# Starting experiment for: squat (featured features)
# ==================================================
# Epoch 1/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.8216 - mae: 1.2190 - val_loss: 0.0312 - val_mae: 0.2002 - learning_rate: 0.0050
# Epoch 2/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1729 - mae: 0.4781 - val_loss: 0.0652 - val_mae: 0.3042 - learning_rate: 0.0050
# Epoch 3/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1050 - mae: 0.3605 - val_loss: 0.0361 - val_mae: 0.2153 - learning_rate: 0.0050
# Epoch 4/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0614 - mae: 0.2778 - val_loss: 0.0452 - val_mae: 0.2428 - learning_rate: 0.0050
# Epoch 5/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0399 - mae: 0.2218 - val_loss: 0.0316 - val_mae: 0.2013 - learning_rate: 0.0050
# Epoch 6/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0313 - mae: 0.1991 - val_loss: 0.0346 - val_mae: 0.2148 - learning_rate: 0.0050
# Epoch 7/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0250 - mae: 0.1746 - val_loss: 0.0304 - val_mae: 0.2009 - learning_rate: 0.0050
# Epoch 8/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0221 - mae: 0.1607 - val_loss: 0.0237 - val_mae: 0.1745 - learning_rate: 0.0050
# Epoch 9/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0221 - mae: 0.1646 - val_loss: 0.0239 - val_mae: 0.1757 - learning_rate: 0.0050
# Epoch 10/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0210 - mae: 0.1632 - val_loss: 0.0209 - val_mae: 0.1640 - learning_rate: 0.0050
# Epoch 11/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0181 - mae: 0.1481 - val_loss: 0.0182 - val_mae: 0.1514 - learning_rate: 0.0050
# Epoch 12/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0203 - mae: 0.1603 - val_loss: 0.0187 - val_mae: 0.1540 - learning_rate: 0.0050
# Epoch 13/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0154 - mae: 0.1366 - val_loss: 0.0193 - val_mae: 0.1565 - learning_rate: 0.0050
# Epoch 14/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0164 - mae: 0.1422 - val_loss: 0.0178 - val_mae: 0.1479 - learning_rate: 0.0050
# Epoch 15/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0157 - mae: 0.1383 - val_loss: 0.0197 - val_mae: 0.1592 - learning_rate: 0.0050
# Epoch 16/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0153 - mae: 0.1371 - val_loss: 0.0175 - val_mae: 0.1492 - learning_rate: 0.0050
# Epoch 17/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0145 - mae: 0.1350 - val_loss: 0.0158 - val_mae: 0.1388 - learning_rate: 0.0050
# Epoch 18/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0145 - mae: 0.1322 - val_loss: 0.0163 - val_mae: 0.1421 - learning_rate: 0.0050
# Epoch 19/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0149 - mae: 0.1340 - val_loss: 0.0144 - val_mae: 0.1311 - learning_rate: 0.0050
# Epoch 20/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0156 - mae: 0.1361 - val_loss: 0.0176 - val_mae: 0.1493 - learning_rate: 0.0050
# Epoch 21/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0152 - mae: 0.1340 - val_loss: 0.0140 - val_mae: 0.1303 - learning_rate: 0.0050
# Epoch 22/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0153 - mae: 0.1330 - val_loss: 0.0165 - val_mae: 0.1453 - learning_rate: 0.0050
# Epoch 23/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0146 - mae: 0.1318 - val_loss: 0.0176 - val_mae: 0.1486 - learning_rate: 0.0050
# Epoch 24/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0135 - mae: 0.1254 - val_loss: 0.0125 - val_mae: 0.1222 - learning_rate: 0.0050
# Epoch 25/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0150 - mae: 0.1315 - val_loss: 0.0147 - val_mae: 0.1337 - learning_rate: 0.0050
# Epoch 26/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0139 - mae: 0.1288 - val_loss: 0.0150 - val_mae: 0.1355 - learning_rate: 0.0050
# Epoch 27/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0133 - mae: 0.1274 - val_loss: 0.0136 - val_mae: 0.1268 - learning_rate: 0.0050
# Epoch 28/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0136 - mae: 0.1253 - val_loss: 0.0139 - val_mae: 0.1283 - learning_rate: 0.0050
# Epoch 29/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0138 - mae: 0.1289 - val_loss: 0.0149 - val_mae: 0.1324 - learning_rate: 0.0050
# Epoch 30/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0127 - mae: 0.1257 - val_loss: 0.0142 - val_mae: 0.1299 - learning_rate: 0.0050
# Epoch 31/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0122 - mae: 0.1209 - val_loss: 0.0127 - val_mae: 0.1218 - learning_rate: 0.0050
# Epoch 32/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0114 - mae: 0.1151 - val_loss: 0.0140 - val_mae: 0.1284 - learning_rate: 0.0050
# Epoch 33/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0112 - mae: 0.1170 - val_loss: 0.0117 - val_mae: 0.1158 - learning_rate: 0.0050
# Epoch 34/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0124 - mae: 0.1229 - val_loss: 0.0136 - val_mae: 0.1287 - learning_rate: 0.0050
# Epoch 35/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0119 - mae: 0.1180 - val_loss: 0.0139 - val_mae: 0.1280 - learning_rate: 0.0050
# Epoch 36/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0118 - mae: 0.1171 - val_loss: 0.0121 - val_mae: 0.1168 - learning_rate: 0.0050
# Epoch 37/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0130 - mae: 0.1242 - val_loss: 0.0149 - val_mae: 0.1318 - learning_rate: 0.0050
# Epoch 38/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0112 - mae: 0.1142 - val_loss: 0.0124 - val_mae: 0.1191 - learning_rate: 0.0050
# Epoch 39/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0115 - mae: 0.1158 - val_loss: 0.0114 - val_mae: 0.1155 - learning_rate: 0.0050
# Epoch 40/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0129 - mae: 0.1235 - val_loss: 0.0134 - val_mae: 0.1229 - learning_rate: 0.0050
# Epoch 41/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0129 - mae: 0.1245 - val_loss: 0.0125 - val_mae: 0.1194 - learning_rate: 0.0050
# Epoch 42/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0112 - mae: 0.1124 - val_loss: 0.0118 - val_mae: 0.1164 - learning_rate: 0.0050
# Epoch 43/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0113 - mae: 0.1150 - val_loss: 0.0118 - val_mae: 0.1140 - learning_rate: 0.0050
# Epoch 44/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0114 - mae: 0.1170 - val_loss: 0.0121 - val_mae: 0.1162 - learning_rate: 0.0050
# Epoch 45/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0117 - mae: 0.1134 - val_loss: 0.0131 - val_mae: 0.1218 - learning_rate: 0.0050
# Epoch 46/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0111 - mae: 0.1163 - val_loss: 0.0119 - val_mae: 0.1194 - learning_rate: 0.0050
# Epoch 47/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0133 - mae: 0.1265 - val_loss: 0.0109 - val_mae: 0.1109 - learning_rate: 0.0050
# Epoch 48/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0103 - mae: 0.1115 - val_loss: 0.0109 - val_mae: 0.1135 - learning_rate: 0.0050
# Epoch 49/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0107 - mae: 0.1110 - val_loss: 0.0109 - val_mae: 0.1130 - learning_rate: 0.0050
# Epoch 50/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0109 - mae: 0.1092 - val_loss: 0.0111 - val_mae: 0.1102 - learning_rate: 0.0050
# Epoch 51/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0100 - mae: 0.1055 - val_loss: 0.0118 - val_mae: 0.1159 - learning_rate: 0.0050
# Epoch 52/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0099 - mae: 0.1072 - val_loss: 0.0116 - val_mae: 0.1151 - learning_rate: 0.0050
# Epoch 53/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0101 - mae: 0.1068 - val_loss: 0.0111 - val_mae: 0.1122 - learning_rate: 0.0050
# Epoch 54/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0108 - mae: 0.1076 - val_loss: 0.0122 - val_mae: 0.1200 - learning_rate: 0.0050
# Epoch 55/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0097 - mae: 0.1077 - val_loss: 0.0131 - val_mae: 0.1197 - learning_rate: 0.0050
# Epoch 56/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0090 - mae: 0.1004 - val_loss: 0.0107 - val_mae: 0.1073 - learning_rate: 0.0050
# Epoch 57/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0091 - mae: 0.1033 - val_loss: 0.0106 - val_mae: 0.1078 - learning_rate: 0.0050
# Epoch 58/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0094 - mae: 0.1027 - val_loss: 0.0126 - val_mae: 0.1172 - learning_rate: 0.0050
# Epoch 59/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0094 - mae: 0.1029 - val_loss: 0.0101 - val_mae: 0.1051 - learning_rate: 0.0050
# Epoch 60/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0083 - mae: 0.0965 - val_loss: 0.0109 - val_mae: 0.1087 - learning_rate: 0.0050
# Epoch 61/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0082 - mae: 0.0981 - val_loss: 0.0107 - val_mae: 0.1092 - learning_rate: 0.0050
# Epoch 62/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0099 - mae: 0.1062 - val_loss: 0.0100 - val_mae: 0.1067 - learning_rate: 0.0050
# Epoch 63/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0096 - mae: 0.1054 - val_loss: 0.0133 - val_mae: 0.1213 - learning_rate: 0.0050
# Epoch 64/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0108 - mae: 0.1115 - val_loss: 0.0130 - val_mae: 0.1206 - learning_rate: 0.0050
# Epoch 65/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0097 - mae: 0.1062 - val_loss: 0.0112 - val_mae: 0.1074 - learning_rate: 0.0050
# Epoch 66/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0117 - mae: 0.1138 - val_loss: 0.0103 - val_mae: 0.1067 - learning_rate: 0.0050
# Epoch 67/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0094 - mae: 0.1009 - val_loss: 0.0116 - val_mae: 0.1155 - learning_rate: 0.0050
# Epoch 68/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0100 - mae: 0.1066 - val_loss: 0.0108 - val_mae: 0.1067 - learning_rate: 0.0050
# Epoch 69/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0098 - mae: 0.1057 - val_loss: 0.0123 - val_mae: 0.1174 - learning_rate: 0.0050
# Epoch 70/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0100 - mae: 0.1033 - val_loss: 0.0116 - val_mae: 0.1125 - learning_rate: 0.0050
# Epoch 71/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0095 - mae: 0.1047 - val_loss: 0.0114 - val_mae: 0.1108 - learning_rate: 0.0050
# Epoch 72/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0093 - mae: 0.1014 - val_loss: 0.0102 - val_mae: 0.1055 - learning_rate: 0.0050
# Epoch 73/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0081 - mae: 0.0968 - val_loss: 0.0103 - val_mae: 0.1064 - learning_rate: 0.0025
# Epoch 74/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0070 - mae: 0.0893 - val_loss: 0.0094 - val_mae: 0.0990 - learning_rate: 0.0025
# Epoch 75/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0069 - mae: 0.0873 - val_loss: 0.0102 - val_mae: 0.1016 - learning_rate: 0.0025
# Epoch 76/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0066 - mae: 0.0839 - val_loss: 0.0096 - val_mae: 0.1001 - learning_rate: 0.0025
# Epoch 77/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0071 - mae: 0.0879 - val_loss: 0.0094 - val_mae: 0.1015 - learning_rate: 0.0025
# Epoch 78/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0070 - mae: 0.0879 - val_loss: 0.0091 - val_mae: 0.0995 - learning_rate: 0.0025
# Epoch 79/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0068 - mae: 0.0844 - val_loss: 0.0094 - val_mae: 0.0970 - learning_rate: 0.0025
# Epoch 80/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0072 - mae: 0.0893 - val_loss: 0.0091 - val_mae: 0.1000 - learning_rate: 0.0025
# Epoch 81/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0081 - mae: 0.0928 - val_loss: 0.0092 - val_mae: 0.0979 - learning_rate: 0.0025
# Epoch 82/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0078 - mae: 0.0974 - val_loss: 0.0101 - val_mae: 0.1021 - learning_rate: 0.0025
# Epoch 83/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0073 - mae: 0.0888 - val_loss: 0.0097 - val_mae: 0.1015 - learning_rate: 0.0025
# Epoch 84/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0075 - mae: 0.0896 - val_loss: 0.0087 - val_mae: 0.0954 - learning_rate: 0.0025
# Epoch 85/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0070 - mae: 0.0884 - val_loss: 0.0089 - val_mae: 0.0992 - learning_rate: 0.0025
# Epoch 86/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0057 - mae: 0.0804 - val_loss: 0.0089 - val_mae: 0.0964 - learning_rate: 0.0025
# Epoch 87/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0065 - mae: 0.0833 - val_loss: 0.0101 - val_mae: 0.1014 - learning_rate: 0.0025
# Epoch 88/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0064 - mae: 0.0844 - val_loss: 0.0085 - val_mae: 0.0924 - learning_rate: 0.0025
# Epoch 89/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0070 - mae: 0.0869 - val_loss: 0.0089 - val_mae: 0.0960 - learning_rate: 0.0025
# Epoch 90/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0080 - mae: 0.0905 - val_loss: 0.0098 - val_mae: 0.1002 - learning_rate: 0.0025
# Epoch 91/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0060 - mae: 0.0786 - val_loss: 0.0090 - val_mae: 0.0989 - learning_rate: 0.0025
# Epoch 92/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0063 - mae: 0.0820 - val_loss: 0.0105 - val_mae: 0.1048 - learning_rate: 0.0025
# Epoch 93/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0067 - mae: 0.0864 - val_loss: 0.0100 - val_mae: 0.1027 - learning_rate: 0.0025
# Epoch 94/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0066 - mae: 0.0814 - val_loss: 0.0098 - val_mae: 0.1014 - learning_rate: 0.0025
# Epoch 95/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0063 - mae: 0.0806 - val_loss: 0.0103 - val_mae: 0.1023 - learning_rate: 0.0025
# Epoch 96/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0063 - mae: 0.0814 - val_loss: 0.0096 - val_mae: 0.1002 - learning_rate: 0.0025
# Epoch 97/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0067 - mae: 0.0850 - val_loss: 0.0092 - val_mae: 0.1014 - learning_rate: 0.0025
# Epoch 98/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0070 - mae: 0.0861 - val_loss: 0.0086 - val_mae: 0.0958 - learning_rate: 0.0025
# Epoch 99/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0060 - mae: 0.0807 - val_loss: 0.0088 - val_mae: 0.0953 - learning_rate: 0.0012
# Epoch 100/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0057 - mae: 0.0816 - val_loss: 0.0088 - val_mae: 0.0953 - learning_rate: 0.0012
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Shapes - y_val: (234,), y_pred: (234, 1)
#
# Completed experiment for: squat (featured features)
# Final Validation MAE: 0.0924
# Final Validation R2: 0.6241
# Results saved to: /content/drive/MyDrive/msc_data_analytics_thesis_project_pose_estimation/results/squat/featured
#
# ==================================================
# Starting experiment for: bench_press (basic features)
# ==================================================
# Epoch 1/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.6245 - mae: 1.0175 - val_loss: 0.0700 - val_mae: 0.3420 - learning_rate: 0.0050
# Epoch 2/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.1497 - mae: 0.4281 - val_loss: 0.0619 - val_mae: 0.3153 - learning_rate: 0.0050
# Epoch 3/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0570 - mae: 0.2640 - val_loss: 0.0507 - val_mae: 0.2754 - learning_rate: 0.0050
# Epoch 4/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0394 - mae: 0.2210 - val_loss: 0.0401 - val_mae: 0.2460 - learning_rate: 0.0050
# Epoch 5/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0255 - mae: 0.1797 - val_loss: 0.0400 - val_mae: 0.2467 - learning_rate: 0.0050
# Epoch 6/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0213 - mae: 0.1602 - val_loss: 0.0391 - val_mae: 0.2474 - learning_rate: 0.0050
# Epoch 7/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0203 - mae: 0.1574 - val_loss: 0.0328 - val_mae: 0.2195 - learning_rate: 0.0050
# Epoch 8/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0192 - mae: 0.1505 - val_loss: 0.0299 - val_mae: 0.2085 - learning_rate: 0.0050
# Epoch 9/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0162 - mae: 0.1367 - val_loss: 0.0243 - val_mae: 0.1834 - learning_rate: 0.0050
# Epoch 10/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0156 - mae: 0.1347 - val_loss: 0.0199 - val_mae: 0.1648 - learning_rate: 0.0050
# Epoch 11/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0151 - mae: 0.1318 - val_loss: 0.0228 - val_mae: 0.1763 - learning_rate: 0.0050
# Epoch 12/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0149 - mae: 0.1335 - val_loss: 0.0211 - val_mae: 0.1689 - learning_rate: 0.0050
# Epoch 13/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0145 - mae: 0.1305 - val_loss: 0.0177 - val_mae: 0.1525 - learning_rate: 0.0050
# Epoch 14/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0157 - mae: 0.1352 - val_loss: 0.0147 - val_mae: 0.1371 - learning_rate: 0.0050
# Epoch 15/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0149 - mae: 0.1335 - val_loss: 0.0155 - val_mae: 0.1420 - learning_rate: 0.0050
# Epoch 16/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0139 - mae: 0.1267 - val_loss: 0.0148 - val_mae: 0.1363 - learning_rate: 0.0050
# Epoch 17/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0140 - mae: 0.1269 - val_loss: 0.0155 - val_mae: 0.1404 - learning_rate: 0.0050
# Epoch 18/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0137 - mae: 0.1245 - val_loss: 0.0148 - val_mae: 0.1354 - learning_rate: 0.0050
# Epoch 19/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0141 - mae: 0.1305 - val_loss: 0.0148 - val_mae: 0.1357 - learning_rate: 0.0050
# Epoch 20/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0130 - mae: 0.1234 - val_loss: 0.0136 - val_mae: 0.1284 - learning_rate: 0.0050
# Epoch 21/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0133 - mae: 0.1256 - val_loss: 0.0134 - val_mae: 0.1257 - learning_rate: 0.0050
# Epoch 22/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0123 - mae: 0.1230 - val_loss: 0.0149 - val_mae: 0.1364 - learning_rate: 0.0050
# Epoch 23/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0133 - mae: 0.1257 - val_loss: 0.0136 - val_mae: 0.1313 - learning_rate: 0.0050
# Epoch 24/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0118 - mae: 0.1184 - val_loss: 0.0118 - val_mae: 0.1191 - learning_rate: 0.0050
# Epoch 25/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0120 - mae: 0.1204 - val_loss: 0.0124 - val_mae: 0.1215 - learning_rate: 0.0050
# Epoch 26/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0112 - mae: 0.1151 - val_loss: 0.0115 - val_mae: 0.1162 - learning_rate: 0.0050
# Epoch 27/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0115 - mae: 0.1162 - val_loss: 0.0128 - val_mae: 0.1247 - learning_rate: 0.0050
# Epoch 28/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0111 - mae: 0.1124 - val_loss: 0.0115 - val_mae: 0.1140 - learning_rate: 0.0050
# Epoch 29/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0101 - mae: 0.1095 - val_loss: 0.0107 - val_mae: 0.1101 - learning_rate: 0.0050
# Epoch 30/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0101 - mae: 0.1111 - val_loss: 0.0116 - val_mae: 0.1171 - learning_rate: 0.0050
# Epoch 31/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0108 - mae: 0.1134 - val_loss: 0.0122 - val_mae: 0.1206 - learning_rate: 0.0050
# Epoch 32/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0097 - mae: 0.1073 - val_loss: 0.0123 - val_mae: 0.1197 - learning_rate: 0.0050
# Epoch 33/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0093 - mae: 0.1059 - val_loss: 0.0124 - val_mae: 0.1225 - learning_rate: 0.0050
# Epoch 34/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0098 - mae: 0.1070 - val_loss: 0.0114 - val_mae: 0.1146 - learning_rate: 0.0050
# Epoch 35/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0095 - mae: 0.1066 - val_loss: 0.0100 - val_mae: 0.1052 - learning_rate: 0.0050
# Epoch 36/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0085 - mae: 0.1019 - val_loss: 0.0103 - val_mae: 0.1081 - learning_rate: 0.0050
# Epoch 37/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0094 - mae: 0.1083 - val_loss: 0.0112 - val_mae: 0.1137 - learning_rate: 0.0050
# Epoch 38/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0096 - mae: 0.1075 - val_loss: 0.0097 - val_mae: 0.1080 - learning_rate: 0.0050
# Epoch 39/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0085 - mae: 0.0997 - val_loss: 0.0097 - val_mae: 0.1058 - learning_rate: 0.0050
# Epoch 40/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0077 - mae: 0.0972 - val_loss: 0.0103 - val_mae: 0.1108 - learning_rate: 0.0050
# Epoch 41/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0087 - mae: 0.1011 - val_loss: 0.0114 - val_mae: 0.1158 - learning_rate: 0.0050
# Epoch 42/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0066 - mae: 0.0890 - val_loss: 0.0105 - val_mae: 0.1085 - learning_rate: 0.0050
# Epoch 43/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0077 - mae: 0.0934 - val_loss: 0.0098 - val_mae: 0.1058 - learning_rate: 0.0050
# Epoch 44/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0064 - mae: 0.0892 - val_loss: 0.0102 - val_mae: 0.1103 - learning_rate: 0.0050
# Epoch 45/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0080 - mae: 0.0976 - val_loss: 0.0095 - val_mae: 0.1009 - learning_rate: 0.0050
# Epoch 46/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0069 - mae: 0.0928 - val_loss: 0.0106 - val_mae: 0.1111 - learning_rate: 0.0050
# Epoch 47/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0102 - mae: 0.1128 - val_loss: 0.0098 - val_mae: 0.1079 - learning_rate: 0.0050
# Epoch 48/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0076 - mae: 0.0952 - val_loss: 0.0105 - val_mae: 0.1081 - learning_rate: 0.0050
# Epoch 49/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0074 - mae: 0.0929 - val_loss: 0.0108 - val_mae: 0.1103 - learning_rate: 0.0050
# Epoch 50/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0081 - mae: 0.0977 - val_loss: 0.0095 - val_mae: 0.1026 - learning_rate: 0.0050
# Epoch 51/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0074 - mae: 0.0916 - val_loss: 0.0104 - val_mae: 0.1066 - learning_rate: 0.0050
# Epoch 52/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0063 - mae: 0.0891 - val_loss: 0.0092 - val_mae: 0.1024 - learning_rate: 0.0050
# Epoch 53/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0058 - mae: 0.0840 - val_loss: 0.0092 - val_mae: 0.1030 - learning_rate: 0.0050
# Epoch 54/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0057 - mae: 0.0821 - val_loss: 0.0089 - val_mae: 0.1006 - learning_rate: 0.0050
# Epoch 55/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0056 - mae: 0.0824 - val_loss: 0.0085 - val_mae: 0.0986 - learning_rate: 0.0050
# Epoch 56/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0054 - mae: 0.0811 - val_loss: 0.0090 - val_mae: 0.1007 - learning_rate: 0.0050
# Epoch 57/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0064 - mae: 0.0866 - val_loss: 0.0100 - val_mae: 0.1060 - learning_rate: 0.0050
# Epoch 58/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0066 - mae: 0.0885 - val_loss: 0.0087 - val_mae: 0.0991 - learning_rate: 0.0050
# Epoch 59/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0057 - mae: 0.0808 - val_loss: 0.0111 - val_mae: 0.1102 - learning_rate: 0.0050
# Epoch 60/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0054 - mae: 0.0814 - val_loss: 0.0098 - val_mae: 0.1018 - learning_rate: 0.0050
# Epoch 61/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0049 - mae: 0.0762 - val_loss: 0.0083 - val_mae: 0.0935 - learning_rate: 0.0050
# Epoch 62/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0053 - mae: 0.0812 - val_loss: 0.0090 - val_mae: 0.0980 - learning_rate: 0.0050
# Epoch 63/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0050 - mae: 0.0782 - val_loss: 0.0098 - val_mae: 0.1055 - learning_rate: 0.0050
# Epoch 64/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0074 - mae: 0.0917 - val_loss: 0.0102 - val_mae: 0.1080 - learning_rate: 0.0050
# Epoch 65/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0066 - mae: 0.0871 - val_loss: 0.0100 - val_mae: 0.1051 - learning_rate: 0.0050
# Epoch 66/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0045 - mae: 0.0729 - val_loss: 0.0084 - val_mae: 0.0977 - learning_rate: 0.0050
# Epoch 67/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0044 - mae: 0.0723 - val_loss: 0.0088 - val_mae: 0.0975 - learning_rate: 0.0050
# Epoch 68/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0044 - mae: 0.0713 - val_loss: 0.0082 - val_mae: 0.0961 - learning_rate: 0.0050
# Epoch 69/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0044 - mae: 0.0729 - val_loss: 0.0090 - val_mae: 0.0986 - learning_rate: 0.0050
# Epoch 70/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0048 - mae: 0.0735 - val_loss: 0.0102 - val_mae: 0.1047 - learning_rate: 0.0050
# Epoch 71/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0049 - mae: 0.0763 - val_loss: 0.0087 - val_mae: 0.0980 - learning_rate: 0.0050
# Epoch 72/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0050 - mae: 0.0774 - val_loss: 0.0090 - val_mae: 0.0972 - learning_rate: 0.0050
# Epoch 73/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0046 - mae: 0.0723 - val_loss: 0.0095 - val_mae: 0.1036 - learning_rate: 0.0050
# Epoch 74/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0047 - mae: 0.0706 - val_loss: 0.0094 - val_mae: 0.1023 - learning_rate: 0.0050
# Epoch 75/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0044 - mae: 0.0713 - val_loss: 0.0088 - val_mae: 0.0986 - learning_rate: 0.0050
# Epoch 76/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0046 - mae: 0.0730 - val_loss: 0.0080 - val_mae: 0.0945 - learning_rate: 0.0050
# Epoch 77/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0036 - mae: 0.0660 - val_loss: 0.0081 - val_mae: 0.0921 - learning_rate: 0.0050
# Epoch 78/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0039 - mae: 0.0679 - val_loss: 0.0081 - val_mae: 0.0917 - learning_rate: 0.0050
# Epoch 79/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0041 - mae: 0.0677 - val_loss: 0.0100 - val_mae: 0.1022 - learning_rate: 0.0050
# Epoch 80/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0045 - mae: 0.0724 - val_loss: 0.0094 - val_mae: 0.1000 - learning_rate: 0.0050
# Epoch 81/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0040 - mae: 0.0680 - val_loss: 0.0094 - val_mae: 0.0967 - learning_rate: 0.0050
# Epoch 82/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0036 - mae: 0.0668 - val_loss: 0.0086 - val_mae: 0.0922 - learning_rate: 0.0050
# Epoch 83/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0041 - mae: 0.0686 - val_loss: 0.0087 - val_mae: 0.0951 - learning_rate: 0.0050
# Epoch 84/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0039 - mae: 0.0678 - val_loss: 0.0092 - val_mae: 0.1002 - learning_rate: 0.0050
# Epoch 85/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0051 - mae: 0.0762 - val_loss: 0.0084 - val_mae: 0.0968 - learning_rate: 0.0050
# Epoch 86/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0034 - mae: 0.0626 - val_loss: 0.0087 - val_mae: 0.0969 - learning_rate: 0.0050
# Epoch 87/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0036 - mae: 0.0638 - val_loss: 0.0079 - val_mae: 0.0914 - learning_rate: 0.0025
# Epoch 88/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0034 - mae: 0.0652 - val_loss: 0.0077 - val_mae: 0.0916 - learning_rate: 0.0025
# Epoch 89/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0030 - mae: 0.0602 - val_loss: 0.0083 - val_mae: 0.0924 - learning_rate: 0.0025
# Epoch 90/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0031 - mae: 0.0608 - val_loss: 0.0077 - val_mae: 0.0905 - learning_rate: 0.0025
# Epoch 91/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0031 - mae: 0.0598 - val_loss: 0.0077 - val_mae: 0.0925 - learning_rate: 0.0025
# Epoch 92/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0028 - mae: 0.0581 - val_loss: 0.0077 - val_mae: 0.0893 - learning_rate: 0.0025
# Epoch 93/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0028 - mae: 0.0572 - val_loss: 0.0071 - val_mae: 0.0893 - learning_rate: 0.0025
# Epoch 94/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0030 - mae: 0.0578 - val_loss: 0.0071 - val_mae: 0.0875 - learning_rate: 0.0025
# Epoch 95/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0026 - mae: 0.0555 - val_loss: 0.0075 - val_mae: 0.0898 - learning_rate: 0.0025
# Epoch 96/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0031 - mae: 0.0595 - val_loss: 0.0073 - val_mae: 0.0882 - learning_rate: 0.0025
# Epoch 97/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0023 - mae: 0.0516 - val_loss: 0.0070 - val_mae: 0.0847 - learning_rate: 0.0025
# Epoch 98/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0025 - mae: 0.0548 - val_loss: 0.0069 - val_mae: 0.0864 - learning_rate: 0.0025
# Epoch 99/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0029 - mae: 0.0579 - val_loss: 0.0075 - val_mae: 0.0859 - learning_rate: 0.0025
# Epoch 100/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0033 - mae: 0.0606 - val_loss: 0.0104 - val_mae: 0.1020 - learning_rate: 0.0025
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Shapes - y_val: (269,), y_pred: (269, 1)
#
# Completed experiment for: bench_press (basic features)
# Final Validation MAE: 0.0864
# Final Validation R2: 0.5602
# Results saved to: /content/drive/MyDrive/msc_data_analytics_thesis_project_pose_estimation/results/bench_press/basic
#
# ==================================================
# Starting experiment for: bench_press (featured features)
# ==================================================
# Epoch 1/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.5634 - mae: 0.9533 - val_loss: 0.0734 - val_mae: 0.3342 - learning_rate: 0.0050
# Epoch 2/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.1316 - mae: 0.4083 - val_loss: 0.0525 - val_mae: 0.2885 - learning_rate: 0.0050
# Epoch 3/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0559 - mae: 0.2637 - val_loss: 0.0585 - val_mae: 0.3098 - learning_rate: 0.0050
# Epoch 4/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0348 - mae: 0.2055 - val_loss: 0.0518 - val_mae: 0.2860 - learning_rate: 0.0050
# Epoch 5/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0259 - mae: 0.1836 - val_loss: 0.0404 - val_mae: 0.2484 - learning_rate: 0.0050
# Epoch 6/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0213 - mae: 0.1629 - val_loss: 0.0364 - val_mae: 0.2381 - learning_rate: 0.0050
# Epoch 7/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0215 - mae: 0.1598 - val_loss: 0.0344 - val_mae: 0.2281 - learning_rate: 0.0050
# Epoch 8/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0170 - mae: 0.1447 - val_loss: 0.0336 - val_mae: 0.2240 - learning_rate: 0.0050
# Epoch 9/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0184 - mae: 0.1489 - val_loss: 0.0261 - val_mae: 0.1922 - learning_rate: 0.0050
# Epoch 10/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0154 - mae: 0.1369 - val_loss: 0.0219 - val_mae: 0.1759 - learning_rate: 0.0050
# Epoch 11/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0170 - mae: 0.1404 - val_loss: 0.0227 - val_mae: 0.1755 - learning_rate: 0.0050
# Epoch 12/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0163 - mae: 0.1403 - val_loss: 0.0178 - val_mae: 0.1521 - learning_rate: 0.0050
# Epoch 13/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0174 - mae: 0.1439 - val_loss: 0.0199 - val_mae: 0.1658 - learning_rate: 0.0050
# Epoch 14/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0160 - mae: 0.1384 - val_loss: 0.0174 - val_mae: 0.1505 - learning_rate: 0.0050
# Epoch 15/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0159 - mae: 0.1394 - val_loss: 0.0142 - val_mae: 0.1315 - learning_rate: 0.0050
# Epoch 16/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0153 - mae: 0.1329 - val_loss: 0.0167 - val_mae: 0.1465 - learning_rate: 0.0050
# Epoch 17/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0146 - mae: 0.1299 - val_loss: 0.0150 - val_mae: 0.1381 - learning_rate: 0.0050
# Epoch 18/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0141 - mae: 0.1282 - val_loss: 0.0148 - val_mae: 0.1380 - learning_rate: 0.0050
# Epoch 19/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0142 - mae: 0.1274 - val_loss: 0.0161 - val_mae: 0.1437 - learning_rate: 0.0050
# Epoch 20/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0144 - mae: 0.1309 - val_loss: 0.0138 - val_mae: 0.1308 - learning_rate: 0.0050
# Epoch 21/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0138 - mae: 0.1276 - val_loss: 0.0144 - val_mae: 0.1340 - learning_rate: 0.0050
# Epoch 22/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0132 - mae: 0.1244 - val_loss: 0.0146 - val_mae: 0.1358 - learning_rate: 0.0050
# Epoch 23/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0134 - mae: 0.1267 - val_loss: 0.0150 - val_mae: 0.1384 - learning_rate: 0.0050
# Epoch 24/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0130 - mae: 0.1244 - val_loss: 0.0161 - val_mae: 0.1459 - learning_rate: 0.0050
# Epoch 25/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0142 - mae: 0.1277 - val_loss: 0.0110 - val_mae: 0.1133 - learning_rate: 0.0050
# Epoch 26/100
# ...
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Shapes - y_val: (504,), y_pred: (504, 1)
#
# Completed experiment for: lunges (basic features)
# Final Validation MAE: 0.0666
# Final Validation R2: 0.6120
# Results saved to: /content/drive/MyDrive/msc_data_analytics_thesis_project_pose_estimation/results/lunges/basic
#
# ==================================================
# Starting experiment for: lunges (featured features)
# ==================================================
# Epoch 1/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 0.4148 - mae: 0.7633 - val_loss: 0.0287 - val_mae: 0.1924 - learning_rate: 0.0050
# Epoch 2/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0612 - mae: 0.2690 - val_loss: 0.0233 - val_mae: 0.1648 - learning_rate: 0.0050
# Epoch 3/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0202 - mae: 0.1515 - val_loss: 0.0167 - val_mae: 0.1316 - learning_rate: 0.0050
# Epoch 4/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0154 - mae: 0.1291 - val_loss: 0.0161 - val_mae: 0.1289 - learning_rate: 0.0050
# Epoch 5/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0141 - mae: 0.1201 - val_loss: 0.0152 - val_mae: 0.1234 - learning_rate: 0.0050
# Epoch 6/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0114 - mae: 0.1092 - val_loss: 0.0126 - val_mae: 0.1117 - learning_rate: 0.0050
# Epoch 7/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0123 - mae: 0.1137 - val_loss: 0.0131 - val_mae: 0.1138 - learning_rate: 0.0050
# Epoch 8/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0115 - mae: 0.1083 - val_loss: 0.0116 - val_mae: 0.1055 - learning_rate: 0.0050
# Epoch 9/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0121 - mae: 0.1101 - val_loss: 0.0110 - val_mae: 0.1051 - learning_rate: 0.0050
# Epoch 10/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0108 - mae: 0.1065 - val_loss: 0.0104 - val_mae: 0.1037 - learning_rate: 0.0050
# Epoch 11/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0121 - mae: 0.1112 - val_loss: 0.0106 - val_mae: 0.1024 - learning_rate: 0.0050
# Epoch 12/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0113 - mae: 0.1054 - val_loss: 0.0103 - val_mae: 0.0996 - learning_rate: 0.0050
# Epoch 13/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0108 - mae: 0.1047 - val_loss: 0.0107 - val_mae: 0.1053 - learning_rate: 0.0050
# Epoch 14/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0114 - mae: 0.1082 - val_loss: 0.0114 - val_mae: 0.1048 - learning_rate: 0.0050
# Epoch 15/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0112 - mae: 0.1073 - val_loss: 0.0107 - val_mae: 0.1026 - learning_rate: 0.0050
# Epoch 16/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0104 - mae: 0.1032 - val_loss: 0.0102 - val_mae: 0.1039 - learning_rate: 0.0050
# Epoch 17/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0109 - mae: 0.1054 - val_loss: 0.0110 - val_mae: 0.1018 - learning_rate: 0.0050
# Epoch 18/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0096 - mae: 0.0985 - val_loss: 0.0104 - val_mae: 0.1009 - learning_rate: 0.0050
# Epoch 19/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0112 - mae: 0.1078 - val_loss: 0.0108 - val_mae: 0.1048 - learning_rate: 0.0050
# Epoch 20/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0116 - mae: 0.1086 - val_loss: 0.0102 - val_mae: 0.1029 - learning_rate: 0.0050
# Epoch 21/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0107 - mae: 0.1042 - val_loss: 0.0102 - val_mae: 0.1010 - learning_rate: 0.0050
# Epoch 22/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0109 - mae: 0.1052 - val_loss: 0.0102 - val_mae: 0.1000 - learning_rate: 0.0050
# Epoch 23/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0102 - mae: 0.1001 - val_loss: 0.0098 - val_mae: 0.0974 - learning_rate: 0.0025
# Epoch 24/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0088 - mae: 0.0955 - val_loss: 0.0103 - val_mae: 0.1007 - learning_rate: 0.0025
# Epoch 25/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0088 - mae: 0.0941 - val_loss: 0.0094 - val_mae: 0.0964 - learning_rate: 0.0025
# Epoch 26/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0095 - mae: 0.0967 - val_loss: 0.0105 - val_mae: 0.1033 - learning_rate: 0.0025
# Epoch 27/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0091 - mae: 0.0961 - val_loss: 0.0099 - val_mae: 0.0978 - learning_rate: 0.0025
# Epoch 28/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0088 - mae: 0.0934 - val_loss: 0.0097 - val_mae: 0.0972 - learning_rate: 0.0025
# Epoch 29/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0080 - mae: 0.0908 - val_loss: 0.0102 - val_mae: 0.0991 - learning_rate: 0.0025
# Epoch 30/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0086 - mae: 0.0955 - val_loss: 0.0098 - val_mae: 0.0986 - learning_rate: 0.0025
# Epoch 31/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0082 - mae: 0.0901 - val_loss: 0.0095 - val_mae: 0.0969 - learning_rate: 0.0025
# Epoch 32/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0079 - mae: 0.0904 - val_loss: 0.0101 - val_mae: 0.0992 - learning_rate: 0.0025
# Epoch 33/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0086 - mae: 0.0928 - val_loss: 0.0091 - val_mae: 0.0923 - learning_rate: 0.0025
# Epoch 34/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0081 - mae: 0.0899 - val_loss: 0.0096 - val_mae: 0.0966 - learning_rate: 0.0025
# Epoch 35/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0080 - mae: 0.0901 - val_loss: 0.0091 - val_mae: 0.0935 - learning_rate: 0.0025
# Epoch 36/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0084 - mae: 0.0924 - val_loss: 0.0092 - val_mae: 0.0954 - learning_rate: 0.0025
# Epoch 37/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0072 - mae: 0.0878 - val_loss: 0.0105 - val_mae: 0.0998 - learning_rate: 0.0025
# Epoch 38/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0083 - mae: 0.0905 - val_loss: 0.0091 - val_mae: 0.0933 - learning_rate: 0.0025
# Epoch 39/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0082 - mae: 0.0934 - val_loss: 0.0092 - val_mae: 0.0929 - learning_rate: 0.0025
# Epoch 40/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0064 - mae: 0.0817 - val_loss: 0.0095 - val_mae: 0.0946 - learning_rate: 0.0025
# Epoch 41/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0083 - mae: 0.0913 - val_loss: 0.0098 - val_mae: 0.0975 - learning_rate: 0.0025
# Epoch 42/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0074 - mae: 0.0893 - val_loss: 0.0089 - val_mae: 0.0935 - learning_rate: 0.0025
# Epoch 43/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0067 - mae: 0.0847 - val_loss: 0.0095 - val_mae: 0.0954 - learning_rate: 0.0025
# Epoch 44/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0082 - mae: 0.0901 - val_loss: 0.0107 - val_mae: 0.1000 - learning_rate: 0.0025
# Epoch 45/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0081 - mae: 0.0902 - val_loss: 0.0085 - val_mae: 0.0918 - learning_rate: 0.0025
# Epoch 46/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0067 - mae: 0.0835 - val_loss: 0.0083 - val_mae: 0.0887 - learning_rate: 0.0025
# Epoch 47/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0073 - mae: 0.0880 - val_loss: 0.0087 - val_mae: 0.0898 - learning_rate: 0.0025
# Epoch 48/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0062 - mae: 0.0803 - val_loss: 0.0081 - val_mae: 0.0862 - learning_rate: 0.0025
# Epoch 49/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0061 - mae: 0.0808 - val_loss: 0.0089 - val_mae: 0.0918 - learning_rate: 0.0025
# Epoch 50/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0069 - mae: 0.0851 - val_loss: 0.0079 - val_mae: 0.0848 - learning_rate: 0.0025
# Epoch 51/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0068 - mae: 0.0832 - val_loss: 0.0083 - val_mae: 0.0884 - learning_rate: 0.0025
# Epoch 52/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0063 - mae: 0.0804 - val_loss: 0.0081 - val_mae: 0.0867 - learning_rate: 0.0025
# Epoch 53/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0060 - mae: 0.0796 - val_loss: 0.0080 - val_mae: 0.0881 - learning_rate: 0.0025
# Epoch 54/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0057 - mae: 0.0776 - val_loss: 0.0084 - val_mae: 0.0880 - learning_rate: 0.0025
# Epoch 55/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0059 - mae: 0.0805 - val_loss: 0.0077 - val_mae: 0.0864 - learning_rate: 0.0025
# Epoch 56/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0057 - mae: 0.0779 - val_loss: 0.0082 - val_mae: 0.0894 - learning_rate: 0.0025
# Epoch 57/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0066 - mae: 0.0823 - val_loss: 0.0086 - val_mae: 0.0897 - learning_rate: 0.0025
# Epoch 58/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0058 - mae: 0.0778 - val_loss: 0.0081 - val_mae: 0.0874 - learning_rate: 0.0025
# Epoch 59/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0058 - mae: 0.0787 - val_loss: 0.0079 - val_mae: 0.0856 - learning_rate: 0.0025
# Epoch 60/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0060 - mae: 0.0803 - val_loss: 0.0078 - val_mae: 0.0868 - learning_rate: 0.0025
# Epoch 61/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0059 - mae: 0.0768 - val_loss: 0.0078 - val_mae: 0.0859 - learning_rate: 0.0025
# Epoch 62/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0057 - mae: 0.0768 - val_loss: 0.0082 - val_mae: 0.0868 - learning_rate: 0.0025
# Epoch 63/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0059 - mae: 0.0781 - val_loss: 0.0082 - val_mae: 0.0884 - learning_rate: 0.0025
# Epoch 64/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0057 - mae: 0.0780 - val_loss: 0.0079 - val_mae: 0.0866 - learning_rate: 0.0025
# Epoch 65/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0050 - mae: 0.0732 - val_loss: 0.0074 - val_mae: 0.0837 - learning_rate: 0.0025
# Epoch 66/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0054 - mae: 0.0774 - val_loss: 0.0073 - val_mae: 0.0849 - learning_rate: 0.0025
# Epoch 67/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0050 - mae: 0.0729 - val_loss: 0.0073 - val_mae: 0.0829 - learning_rate: 0.0025
# Epoch 68/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0056 - mae: 0.0761 - val_loss: 0.0099 - val_mae: 0.1001 - learning_rate: 0.0025
# Epoch 69/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0063 - mae: 0.0804 - val_loss: 0.0079 - val_mae: 0.0873 - learning_rate: 0.0025
# Epoch 70/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0060 - mae: 0.0777 - val_loss: 0.0085 - val_mae: 0.0886 - learning_rate: 0.0025
# Epoch 71/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0061 - mae: 0.0769 - val_loss: 0.0080 - val_mae: 0.0860 - learning_rate: 0.0025
# Epoch 72/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0049 - mae: 0.0713 - val_loss: 0.0076 - val_mae: 0.0846 - learning_rate: 0.0025
# Epoch 73/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0051 - mae: 0.0741 - val_loss: 0.0077 - val_mae: 0.0845 - learning_rate: 0.0025
# Epoch 74/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0046 - mae: 0.0701 - val_loss: 0.0073 - val_mae: 0.0824 - learning_rate: 0.0025
# Epoch 75/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0052 - mae: 0.0731 - val_loss: 0.0076 - val_mae: 0.0837 - learning_rate: 0.0025
# Epoch 76/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0048 - mae: 0.0703 - val_loss: 0.0065 - val_mae: 0.0768 - learning_rate: 0.0012
# Epoch 77/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0047 - mae: 0.0697 - val_loss: 0.0069 - val_mae: 0.0793 - learning_rate: 0.0012
# Epoch 78/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0046 - mae: 0.0676 - val_loss: 0.0070 - val_mae: 0.0782 - learning_rate: 0.0012
# Epoch 79/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0035 - mae: 0.0622 - val_loss: 0.0065 - val_mae: 0.0795 - learning_rate: 0.0012
# Epoch 80/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0037 - mae: 0.0642 - val_loss: 0.0063 - val_mae: 0.0775 - learning_rate: 0.0012
# Epoch 81/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0042 - mae: 0.0662 - val_loss: 0.0061 - val_mae: 0.0764 - learning_rate: 0.0012
# Epoch 82/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0040 - mae: 0.0638 - val_loss: 0.0064 - val_mae: 0.0778 - learning_rate: 0.0012
# Epoch 83/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0041 - mae: 0.0666 - val_loss: 0.0065 - val_mae: 0.0765 - learning_rate: 0.0012
# Epoch 84/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0039 - mae: 0.0640 - val_loss: 0.0063 - val_mae: 0.0750 - learning_rate: 0.0012
# Epoch 85/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0033 - mae: 0.0601 - val_loss: 0.0062 - val_mae: 0.0757 - learning_rate: 0.0012
# Epoch 86/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0031 - mae: 0.0587 - val_loss: 0.0062 - val_mae: 0.0748 - learning_rate: 0.0012
# Epoch 87/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0035 - mae: 0.0609 - val_loss: 0.0067 - val_mae: 0.0788 - learning_rate: 0.0012
# Epoch 88/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0038 - mae: 0.0624 - val_loss: 0.0063 - val_mae: 0.0757 - learning_rate: 0.0012
# Epoch 89/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0040 - mae: 0.0637 - val_loss: 0.0063 - val_mae: 0.0748 - learning_rate: 0.0012
# Epoch 90/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0033 - mae: 0.0618 - val_loss: 0.0060 - val_mae: 0.0747 - learning_rate: 0.0012
# Epoch 91/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0035 - mae: 0.0597 - val_loss: 0.0065 - val_mae: 0.0778 - learning_rate: 0.0012
# Epoch 92/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0033 - mae: 0.0601 - val_loss: 0.0064 - val_mae: 0.0763 - learning_rate: 0.0012
# Epoch 93/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0035 - mae: 0.0602 - val_loss: 0.0060 - val_mae: 0.0707 - learning_rate: 0.0012
# Epoch 94/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0035 - mae: 0.0592 - val_loss: 0.0063 - val_mae: 0.0756 - learning_rate: 0.0012
# Epoch 95/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0030 - mae: 0.0576 - val_loss: 0.0058 - val_mae: 0.0739 - learning_rate: 0.0012
# Epoch 96/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0034 - mae: 0.0597 - val_loss: 0.0065 - val_mae: 0.0770 - learning_rate: 0.0012
# Epoch 97/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0032 - mae: 0.0584 - val_loss: 0.0060 - val_mae: 0.0745 - learning_rate: 0.0012
# Epoch 98/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0033 - mae: 0.0596 - val_loss: 0.0064 - val_mae: 0.0768 - learning_rate: 0.0012
# Epoch 99/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0031 - mae: 0.0579 - val_loss: 0.0067 - val_mae: 0.0768 - learning_rate: 0.0012
# Epoch 100/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0039 - mae: 0.0625 - val_loss: 0.0065 - val_mae: 0.0763 - learning_rate: 0.0012
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Shapes - y_val: (504,), y_pred: (504, 1)
#
# Completed experiment for: lunges (featured features)
# Final Validation MAE: 0.0739
# Final Validation R2: 0.5050
# Results saved to: /content/drive/MyDrive/msc_data_analytics_thesis_project_pose_estimation/results/lunges/featured
#
# Comparison tables and plots saved to: /content/drive/MyDrive/msc_data_analytics_thesis_project_pose_estimation/results/comparisons
#
# Experiment Summary:
#    exercise features  prediction_mae  prediction_r2  num_epochs_run  final_val_loss
#       squat    basic        0.085468       0.702721             100        0.007544
#       squat featured        0.092430       0.624140             100        0.008763
# bench_press    basic        0.086409       0.560152             100        0.010382
# bench_press featured        0.098631       0.452502             100        0.008707
#    pull_ups    basic        0.091777       0.611881             100        0.008509
#    pull_ups featured        0.087106       0.657120             100        0.007501
#      lunges    basic        0.066588       0.612043             100        0.004535
#      lunges featured        0.073897       0.504983             100        0.006501
